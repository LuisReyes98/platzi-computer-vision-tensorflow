# %% [markdown]
# # Pressure gauge detection model
#
# Objective: Be able to tell the value that is being displayed in a pressure gauge using image detection
#
# ## Phase 1 model selection and environment test
#
#
# ### Steps TO DO for Image Classification
#
# 1. List all posibles labels
# 2. Create labeled dataset of at least 50 images for v1
# 3. Make sure there are enough of each label and the dataset is not biased specially after splitting it into training and test
# 4. Select model for transfer learning
# 5. Build arquitecture and test
#
#
# ### Steps TO DO for Object Detection
#
# 1. List all the posible labels we will work with
# 2. How can identifying the position of the elements on the screen tell us the value of the gauge?
# 3. Create labeled dataset for object segmentation with at least 50 images for v1
# 4. Select model for transfer learning
# 5. Build arquitecture and test
